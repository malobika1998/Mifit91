# %% [markdown]
# <a href="https://colab.research.google.com/github/malobika1998/Mifit91/blob/main/bartamanchadnatala.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

import requests
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
from datetime import datetime

URL = 'https://www.sangbadpratidin.in/'

response = requests.get(URL)

response

news_abvr = 'NONE'
if URL == 'https://www.sangbadpratidin.in':
    news_abvr = 'PRTD'
elif URL == 'https://bartamanpatrika.com/home':
    news_abvr = 'BTMN'
elif URL == 'https://bengali.news18.com/':
    news_abvr = 'NS18'
elif URL == 'https://eisamay.com/':
    news_abvr = 'ESMY'
elif URL == 'https://www.aajkaal.in/':
    news_abvr = 'AJKL'


datetime.today().strftime('%d-%m-%Y')

soup = BeautifulSoup(response.content, 'html.parser')
# soup = BeautifulSoup(page_html, 'html.parser')
headlines = soup.find_all('a')
headline_list = []
Id = []
news_id = 1
# for headline in headlines:
#     if len(headline.text.split()) > 5:
#         print(headline.text.strip(), '\n')
#         headline_list.append(headline.text.strip())
#         Id.append(f"BN/news_abvr/"+datetime.today().strftime('%y%m%d')+"/"+"{0:0=3d}".format(news_id))
#         news_id += 1
medias = soup.find_all('div', class_="media")
news_links = []
for media in medias:
  news_links.append(media.parent['href'])
news_links
news_headlines = []
news_bodies = []
for ind,link in enumerate(news_links):
  try:
      response = requests.get(link)
      soup = BeautifulSoup(response.content, 'html.parser')
      heading = soup.find('h1', class_='news_title fnt_bold')
      date = list(soup.find('ul', class_='posted').children)[1].find('span').text
      print(date)
      article = soup.find('section', class_='full_article_content_side_ad_sec')
      paragraphs = article.find_all('p')
      print(f'\n\nResponse {ind+1}\n\n')
      news_headlines.append(heading.text)
      print(heading.text)
      for paragraph in paragraphs:
        print(list(paragraph.children)[0])
  except Exception as e:
    continue
# Out:
# January 14, 2025 2:34 pm
#
#
# Response 1
#
#
# মেদিনীপুর মেডিক্যালে জন্মানো ৫ শিশুর একজনের অবস্থার অবনতি, হাসপাতালে তদন্তে CID
#
#
# <strong>সম্যক খান, মেদিনীপুর: </strong>
# মেদিনীপুর মেডিক্যাল হাসপাতালে সন্তান প্রসবের পর, পাঁচ প্রসূতির অবস্থা আশঙ্কাজনক হয়ে ওঠে। মারা যান মামণি রুইদাস নামের এক প্রসূতি। বাকিরা চিকিৎসাধীন। তাঁদের সন্তানদের অবস্থা স্থিতিশীল ছিল। তবে আচমকাই রেখা সাউয়ের সন্তানের অবস্থার অবনতি হয়েছে। তার একাধিক সমস্যা দেখা দিয়েছে বলে খবর। সদ্যোজাতকে মেদিনীপুর মেডিক্যালের এনআইসিউ বিভাগে রাখা হয়েছে। শারীরিক পরীক্ষা করা হচ্ছে। চিকিৎসক তারাপদ ঘোষ জানান, “রেখা সাউয়ের সন্তানের অবস্থা কিছুটা খারাপ। সদ্যোজাতের উপর কড়া নজর রাখা হচ্ছে।” এদিকে রেখার শারীরিক অবস্থা আগের থেকে কিছুটা ভালো বলে জানা যাচ্ছে।
# ...

# %%
import pandas as pd
import numpy as np

import requests
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
from datetime import datetime

URL = 'https://www.sangbadpratidin.in/chadnatola/'

response = requests.get(URL)

response

news_abvr = 'NONE'
if URL == 'https://www.sangbadpratidin.in':
    news_abvr = 'PRTD'
elif URL == 'https://bartamanpatrika.com/home':
    news_abvr = 'BTMN'
elif URL == 'https://bengali.news18.com/':
    news_abvr = 'NS18'
elif URL == 'https://eisamay.com/':
    news_abvr = 'ESMY'
elif URL == 'https://www.aajkaal.in/':
    news_abvr = 'AJKL'


datetime.today().strftime('%d-%m-%Y')

soup = BeautifulSoup(response.content, 'html.parser')
# soup = BeautifulSoup(page_html, 'html.parser')
# headlines = soup.find_all('a')
headline_list = []
Id = []
news_id = 1
# for headline in headlines:
#     if len(headline.text.split()) > 5:
#         print(headline.text.strip(), '\n')
#         headline_list.append(headline.text.strip())
#         Id.append(f"BN/news_abvr/"+datetime.today().strftime('%y%m%d')+"/"+"{0:0=3d}".format(news_id))
#         news_id += 1
medias1 = soup.find('div', class_="chadna_top_intro_grid_sec")
medias=medias1.find_all('a')
news_links = []
for media in medias:
  news_links.append(media['href'])
news_links
news_headlines = []
news_bodies = []
for ind,link in enumerate(news_links):
  try:
      response = requests.get(link)
      soup = BeautifulSoup(response.content, 'html.parser')
      heading = soup.find('h1', class_='news_title fnt_bold')
      date = list(soup.find('ul', class_='posted').children)[1].find('span').text
      print(date)
      article = soup.find('section', class_='full_article_content_side_ad_sec')
      paragraphs = article.find_all('p')
      print(f'\n\nResponse {ind+1}\n\n')
      news_headlines.append(heading.text)
      print(heading.text)
      for paragraph in paragraphs:
        print(list(paragraph.children)[0])
  except Exception as e:
    continue
# Out:
# December 6, 2024 8:27 pm
#
#
# Response 1
#
#
# চেনা ছক ভেঙে বদলাচ্ছে বিয়ের কার্ড, নতুন যুগে ঝোঁক ডিজিটাল কার্ডে
#
#
# কথায় বলে, যার বিয়ে তাঁর হুঁশ নেই, পাড়াপড়শির ঘুম নেই। সত্যিই তো, বিয়ে কি আর কম ঝক্কির ব্যাপার! তা নিয়ে মাথাব্যথা যদি থেকেও থাকে, তবে তেমন দোষের নয়। বহু রীতিনীতি, উপাচার জুড়ে আছে বিয়ের সঙ্গে। আর তারই মধ্যে খুব দরকারি একটি বিষয় হল নেমন্তন্ন করা। আত্মীয় হোক বা বন্ধুবান্ধব, বাড়ি বাড়ি গিয়ে বলার সময় শুধু হাতে কি যাওয়া চলে! এককালে সে রীতি ছিল বটে। তবে সময় বদলেছে। আর তাই কার্ড ছাড়া বিয়ের নিমন্ত্রণ এখন যেন ভাবাই যায় না। তবে ডিজিটাল যুগে সেই কার্ডের ধরনেও এসেছে বেশ বদল।
# বিয়ের কার্ডে কাজের তথ্য সামান্যই। বিয়ের দিনক্ষণ, পাত্রপাত্রীর পরিচয় ইত্যাদি। তবে বিয়ের কার্ড বলতে সেটুকু মাত্র বোঝায় না। আঙ্গিক এখানে যথেষ্ট গুরুত্বপূর্ণ। আর তাই যেমন-তেমন কার্ড হলেই চলে না, বিয়ের কার্ডের নান্দনিক দিকটিও মাথায় রাখতে হয়।
# ...

# %%
import pandas as pd
import numpy as np

import requests
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
from datetime import datetime

URL = 'https://www.sangbadpratidin.in/category/kolkata/'

response = requests.get(URL)

response

news_abvr = 'NONE'
if URL == 'https://www.sangbadpratidin.in':
    news_abvr = 'PRTD'
elif URL == 'https://bartamanpatrika.com/home':
    news_abvr = 'BTMN'
elif URL == 'https://bengali.news18.com/':
    news_abvr = 'NS18'
elif URL == 'https://eisamay.com/':
    news_abvr = 'ESMY'
elif URL == 'https://www.aajkaal.in/':
    news_abvr = 'AJKL'


datetime.today().strftime('%d-%m-%Y')

soup = BeautifulSoup(response.content, 'html.parser')
# soup = BeautifulSoup(page_html, 'html.parser')
# headlines = soup.find_all('a')
headline_list = []
Id = []
news_id = 1
# for headline in headlines:
#     if len(headline.text.split()) > 5:
#         print(headline.text.strip(), '\n')
#         headline_list.append(headline.text.strip())
#         Id.append(f"BN/news_abvr/"+datetime.today().strftime('%y%m%d')+"/"+"{0:0=3d}".format(news_id))
#         news_id += 1
medias1 = soup.find('div', class_="row")
medias=medias1.find_all('a')
news_links = []
for media in medias:
  news_links.append(media['href'])
news_links
news_headlines = []
news_bodies = []
for ind,link in enumerate(news_links):
  try:
      response = requests.get(link)
      soup = BeautifulSoup(response.content, 'html.parser')
      heading = soup.find('h1', class_='news_title fnt_bold')
      date = list(soup.find('ul', class_='posted').children)[1].find('span').text
      print(date)
      article = soup.find('section', class_='full_article_content_side_ad_sec')
      paragraphs = article.find_all('p')
      print(f'\n\nResponse {ind+1}\n\n')
      news_headlines.append(heading.text)
      print(heading.text)
      for paragraph in paragraphs:
        print(list(paragraph.children)[0])
  except Exception as e:
    continue
# Out:
# January 14, 2025 11:46 am
#
#
# Response 1
#
#
# বড় সাফল্য জেলা পুলিশের, পাচারের আগেই বর্ধমানে উদ্ধার ৭২ কেজি গাঁজা
#
#
# <strong>অর্ক দে, বর্ধমান:</strong>
# পুলিশ সূত্রে জানা গিয়েছে, গাঁজা পাচার হওয়ার আগাম খবর গোপন সূত্রে পাওয়া গিয়েছিল। তারপরই বর্ধমান ও দেওয়ানদিঘি থানার পুলিশ যৌথ অভিযান চালায়। বিশেষ তদন্তকারী দলের তরফে নাকাচেকিংয়ের ব্যবস্থা হয়। এদিন সকালে একটি ছোট চার চাকার গাড়ি দেখে পুলিশের সন্দেহ হয়। সেই গাড়িটি দাঁড় করিয়ে চালককে জিজ্ঞাসাবাদ করা হয়। কথায় অসঙ্গতি ধরা পড়ায় শুরু হয় গাড়ি তল্লাশি। ভিতর থেকে পাওয়া যায় বেশ কয়েকটি বড় আকারের পার্সেল। সেগুলি খুলতেই বেরিয়ে পড়ে গাঁজা।
# ...

# %%
import pandas as pd
import numpy as np

import requests
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
from datetime import datetime

URL = 'https://www.sangbadpratidin.in/category/bengal/'

response = requests.get(URL)

response

news_abvr = 'NONE'
if URL == 'https://www.sangbadpratidin.in':
    news_abvr = 'PRTD'
elif URL == 'https://bartamanpatrika.com/home':
    news_abvr = 'BTMN'
elif URL == 'https://bengali.news18.com/':
    news_abvr = 'NS18'
elif URL == 'https://eisamay.com/':
    news_abvr = 'ESMY'
elif URL == 'https://www.aajkaal.in/':
    news_abvr = 'AJKL'


datetime.today().strftime('%d-%m-%Y')

soup = BeautifulSoup(response.content, 'html.parser')
# soup = BeautifulSoup(page_html, 'html.parser')
# headlines = soup.find_all('a')
headline_list = []
Id = []
news_id = 1
# for headline in headlines:
#     if len(headline.text.split()) > 5:
#         print(headline.text.strip(), '\n')
#         headline_list.append(headline.text.strip())
#         Id.append(f"BN/news_abvr/"+datetime.today().strftime('%y%m%d')+"/"+"{0:0=3d}".format(news_id))
#         news_id += 1
medias1 = soup.find('div', class_="page_inner_wrapper")
medias=medias1.find_all('a')
news_links = []
for media in medias:
  news_links.append(media['href'])
news_links
news_headlines = []
news_bodies = []
for ind,link in enumerate(news_links):
  try:
      response = requests.get(link)
      soup = BeautifulSoup(response.content, 'html.parser')
      heading = soup.find('h1', class_='news_title fnt_bold')
      date = list(soup.find('ul', class_='posted').children)[1].find('span').text
      print(date)
      article = soup.find('section', class_='full_article_content_side_ad_sec')
      paragraphs = article.find_all('p')
      #print(paragraphs)
      print(f'\n\nResponse {ind+1}\n\n')
      news_headlines.append(heading.text)
      print(heading.text)
      for paragraph in paragraphs:
        print(list(paragraph.children)[0])
  except Exception as e:
    continue
# Out:
# January 14, 2025 2:44 pm
#
#
# Response 3
#
#
# দিনের পর দিন ‘বেআইনি’ নির্মাণ, দাসপুরে বুলডোজার চালিয়ে ভাঙা হল সিপিএম পার্টি অফিস
#
#
# <strong>শ্রীকান্ত পাত্র, ঘাটাল:</strong>
# গত কয়েকদিন ধরে দাসপুর ২ ব্লকজুড়ে সরকারি জায়গা দখলমুক্ত করার জন্য মাইকিং, প্রচার করে ব্লক প্রশাসন। মাইকিংয়ের পরও বেআইনি নির্মাণগুলি সরিয়ে নেওয়ার জন্য জবরদখলকারীরা তাগিদ দেখাননি। অভিযোগ, ঠিক একইভাবে সেচ দপ্তরের জল প্রকল্পের জায়গা দখল করে রানিচকে গড়ে উঠেছিল সিপিএমের পার্টি অফিস। সেচ দপ্তর সূত্রে জানা গিয়েছে, ২২ নভেম্বর রানিচক গ্রামের বাসিন্দারা সেচ দপ্তরের নজরে আনেন ওই বেআইনি পার্টি অফিসটি। যদিও দল থেকে জানানো হয়, সেচ দপ্তর থেকে লিজ নিয়ে ওই কার্যালয় গড়ে তোলা হয়। অথচ নথি দেখতে চাইলে কমরেডরা লিজের কাগজপত্র দেখাতে পারেননি বলে জানান জেলাশাসক। এরপর আর অপেক্ষা করেনি প্রশাসন।
# ...

# %%
import pandas as pd
import numpy as np

import requests
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
from datetime import datetime

URL = 'https://www.sangbadpratidin.in/category/india/'

response = requests.get(URL)

response

news_abvr = 'NONE'
if URL == 'https://www.sangbadpratidin.in':
    news_abvr = 'PRTD'
elif URL == 'https://bartamanpatrika.com/home':
    news_abvr = 'BTMN'
elif URL == 'https://bengali.news18.com/':
    news_abvr = 'NS18'
elif URL == 'https://eisamay.com/':
    news_abvr = 'ESMY'
elif URL == 'https://www.aajkaal.in/':
    news_abvr = 'AJKL'


datetime.today().strftime('%d-%m-%Y')

soup = BeautifulSoup(response.content, 'html.parser')
# soup = BeautifulSoup(page_html, 'html.parser')
# headlines = soup.find_all('a')
headline_list = []
Id = []
news_id = 1
# for headline in headlines:
#     if len(headline.text.split()) > 5:
#         print(headline.text.strip(), '\n')
#         headline_list.append(headline.text.strip())
#         Id.append(f"BN/news_abvr/"+datetime.today().strftime('%y%m%d')+"/"+"{0:0=3d}".format(news_id))
#         news_id += 1
medias1 = soup.find('div', class_="page_inner_wrapper")
medias=medias1.find_all('a')
news_links = []
for media in medias:
  news_links.append(media['href'])
news_links
news_headlines = []
news_bodies = []
for ind,link in enumerate(news_links):
  try:
      response = requests.get(link)
      soup = BeautifulSoup(response.content, 'html.parser')
      heading = soup.find('h1', class_='news_title fnt_bold')
      date = list(soup.find('ul', class_='posted').children)[1].find('span').text
      print(date)
      article = soup.find('section', class_='full_article_content_side_ad_sec')
      paragraphs = article.find_all('p')
      #print(paragraphs)
      print(f'\n\nResponse {ind+1}\n\n')
      news_headlines.append(heading.text)
      print(heading.text)
      for paragraph in paragraphs:
        print(list(paragraph.children)[0])
  except Exception as e:
    continue
# Out:
# January 14, 2025 3:01 pm
#
#
# Response 3
#
#
# ফ্ল্যাট-বাড়ি-জমি, নগদেরও খনি! দুর্নীতির তদন্তে পর্দাফাঁস প্রাক্তন সরকারী কর্মীর
#
#
# <strong>সংবাদ প্রতিদিন ডিজিটাল ডেস্ক:</strong>
# দুর্নীতি দমন শাখার তরফে জানানো হয়েছে, অভিযুক্ত ওই সরকারি কর্মীর নাম রিয়াজ আহমেদ পারায়। তিনি জম্মু ও কাশ্মীর পিডব্লুডি দপ্তরের প্রাক্তন কর্মী ছিলেন। বারামুল্লার বাসিন্দা রিয়াজের বিপুল সম্পত্তি খোঁজ পেয়ে তাঁর বিরুদ্ধে অভিযানে নেমেছিল দুর্নীতি দমন শাখা। দিল্লি, জম্মু ও কাশ্মীর-সহ অভিযুক্তের একাধিক ঠিকানায় তল্লাশি চালানো হয়। এই অভিযানে তাঁর বারামুল্লার বাড়ি থেকে ৫০০ টাকার বান্ডিলে নোটের পাহাড় উদ্ধার হয়। পাশাপাশি তার স্থাবর ও অস্থাবর সম্পত্তির হিসেবও বিশাল।
# ...

# %%
import pandas as pd
import numpy as np

import requests
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
from datetime import datetime

URL = 'https://www.sangbadpratidin.in/category/sports/'

response = requests.get(URL)

response

news_abvr = 'NONE'
if URL == 'https://www.sangbadpratidin.in':
    news_abvr = 'PRTD'
elif URL == 'https://bartamanpatrika.com/home':
    news_abvr = 'BTMN'
elif URL == 'https://bengali.news18.com/':
    news_abvr = 'NS18'
elif URL == 'https://eisamay.com/':
    news_abvr = 'ESMY'
elif URL == 'https://www.aajkaal.in/':
    news_abvr = 'AJKL'


datetime.today().strftime('%d-%m-%Y')

soup = BeautifulSoup(response.content, 'html.parser')
# soup = BeautifulSoup(page_html, 'html.parser')
# headlines = soup.find_all('a')
headline_list = []
Id = []
news_id = 1
# for headline in headlines:
#     if len(headline.text.split()) > 5:
#         print(headline.text.strip(), '\n')
#         headline_list.append(headline.text.strip())
#         Id.append(f"BN/news_abvr/"+datetime.today().strftime('%y%m%d')+"/"+"{0:0=3d}".format(news_id))
#         news_id += 1
medias1 = soup.find('div', class_="page_inner_wrapper")
medias=medias1.find_all('a')
news_links = []
for media in medias:
  news_links.append(media['href'])
news_links
news_headlines = []
news_bodies = []
for ind,link in enumerate(news_links):
  try:
      response = requests.get(link)
      soup = BeautifulSoup(response.content, 'html.parser')
      heading = soup.find('h1', class_='news_title fnt_bold')
      date = list(soup.find('ul', class_='posted').children)[1].find('span').text
      print(date)
      article = soup.find('section', class_='full_article_content_side_ad_sec')
      paragraphs = article.find_all('p')
      #print(paragraphs)
      print(f'\n\nResponse {ind+1}\n\n')
      news_headlines.append(heading.text)
      print(heading.text)
      for paragraph in paragraphs:
        print(list(paragraph.children)[0])
  except Exception as e:
    continue
# Out:
# January 14, 2025 3:07 pm
#
#
# Response 3
#
#
# আগুনের লেলিহান শিখায় ছারখার লস অ্যাঞ্জেলস, আদৌ অলিম্পিক হবে তো?
#
#
# <strong>সংবাদ প্রতিদিন ডিজিটাল ডেস্ক:</strong>
# গত বছর প্যারিস অলিম্পিকের সমাপ্তি অনুষ্ঠানে মশাল তুলে দেওয়া হয়েছিল লস অ্যাঞ্জেলসের হাতে। গত সাত বছর ধরে সেখানে ‘দ্য গ্রেটেস্ট শো অন আর্থ’-এর প্রস্তুতি চলছে। কিন্তু বিধ্বংসী দাবানলের পর তার আয়োজন নিয়ে বড়সড় প্রশ্ন উঠতে শুরু করেছে। ইতিমধ্যে মৃত্যু ঘটেছে ২৪ জনের। গৃহছাড়া অসংখ্য মানুষ। আগুন কবে নিভবে কেউ জানেন না। এই পরিস্থিতিতে প্রায় আগুনে পুড়ে ছারখার একটা শহরে কীভাবে অলিম্পিক আয়োজন সম্ভব?
# ১৭ দিন ধরে চলবে অলিম্পিক। আসতে পারেন প্রায় দেড় কোটি মানুষ। খরচ পড়তে পারে আনুমানিক সাত হাজার কোটি টাকা। অথচ নিঃস্ব অবস্থা থেকে শুরু করতে হবে। হাতে তিন বছরের সামান্য বেশি সময়। কিন্তু প্রশ্ন আরেক জায়গায়। অলিম্পিকের সময়ও যে দাবানলের আতঙ্ক ফিরে আসবে না, তার নিশ্চয়তা কে দেবে? আর লস অ্যাঞ্জেলস শহরের যে জায়গাগুলোকে অলিম্পিকের বিভিন্ন ইভেন্টের জন্য বেছে নেওয়া হয়েছে, সেখানে আগুন লাগার সম্ভাবনা সবচেয়ে বেশি।
# ...

# %%
import pandas as pd
import os

# Define the folder where your output files are stored
output_folder = '/content/outputs/'  # Replace with your folder path

# Collect all CSV files from the folder
csv_files = [os.path.join(output_folder, file) for file in os.listdir(output_folder) if file.endswith('.csv')]

# Initialize an empty list to hold DataFrames
dataframes = []

# Load each CSV file into a DataFrame and append it to the list
for file in csv_files:
    df = pd.read_csv(file)
    dataframes.append(df)

# Concatenate all DataFrames into a single DataFrame
merged_df = pd.concat(dataframes, ignore_index=True)

# Save the merged DataFrame to a new CSV file
output_file = '/content/merged_output.csv'
merged_df.to_csv(output_file, index=False)

print(f"All files have been merged into {output_file}")
